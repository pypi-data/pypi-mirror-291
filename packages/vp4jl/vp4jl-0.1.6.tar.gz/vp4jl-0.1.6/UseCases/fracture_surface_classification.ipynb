# %%
{"nodes":[{"id":"0","type":"keras.load_pytorch_model","position":{"x":235.9271418647677,"y":565.416627724581},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","value":"model.pt","dataType":"string"},"eval":{"title":"eval","dataType":"boolean"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"model":{"title":"model","dataType":"keras.model"}},"title":"load_pytorch_model"},{"id":"1","type":"Flow Control.main","position":{"x":159.08730979449,"y":564.5804175640096},"outputs":{"execOut":{"dataType":"exec"}},"title":"main"},{"id":"3","type":"imageio.read_image","position":{"x":372.2132687802683,"y":283.9796077333815},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","dataType":"string"},"mode":{"title":"mode","dataType":"imageio.ImageReadMode"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"read_image"},{"id":"4","type":"Flow Control.for each loop","position":{"x":752.3715692422566,"y":566.1880493602988},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"list":{"title":"list","dataType":"list"}},"outputs":{"loopBody":{"title":"loop body","dataType":"exec"},"index":{"title":"index","dataType":"integer"},"element":{"title":"element","dataType":"anyDataType"},"complete":{"title":"completed","dataType":"exec"}},"title":"for each loop"},{"id":"5","type":"Log.print","position":{"x":1058.6282254897776,"y":283.5922398655035},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"input":{"title":"objects","value":"","dataType":"anyDataType"}},"outputs":{"execOut":{"dataType":"exec"}},"title":"Print"},{"id":"6","type":"imageio.paths_to_images_in_folder","position":{"x":493.7275249632812,"y":566.0525660453715},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","value":"test_set","dataType":"string"},"format":{"title":"format","dataType":"imageio.ImageFileFormat"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"paths":{"title":"paths","dataType":"list"}},"title":"paths_to_images_in_folder"},{"id":"2","type":"keras.predict_as_string","position":{"x":615.4296190266633,"y":283.15818907494486},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"keras_model":{"title":"model","dataType":"keras.model"},"input_image":{"title":"input_image","dataType":"image"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"predicted":{"title":"predicted","dataType":"string"}},"title":"predict_as_string"},{"id":"7","type":"Operators.+","position":{"x":848.516205316274,"y":373.2197433516406},"inputs":{"in1":{"title":"in","dataType":"anyDataType"},"in2":{"value":"\" is \"","dataType":"anyDataType"},"in_0":{"title":"in","dataType":"anyDataType"}},"outputs":{"out":{"title":"out","dataType":"anyDataType"}},"dataType":"anyDataType","title":"+"},{"id":"8","type":"reroute","position":{"x":365.56800044277213,"y":471.2053607647465},"inputs":{"input":{"title":"input","dataType":"anyDataType"}},"outputs":{"output":{"title":"output","dataType":"anyDataType"}},"dataType":"anyDataType","title":"reroute"},{"id":"9","type":"Function & Variable Creation.new function","position":{"x":158.0545540468654,"y":283.6365137247651},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"out_0":{"title":"model","dataType":"anyDataType"},"out_1":{"title":"path","dataType":"anyDataType"}},"nodeRef":null,"title":"predict_on_image"},{"id":"10","type":"reroute","position":{"x":372.02471109567784,"y":430.589184817457},"inputs":{"input":{"title":"input","dataType":"anyDataType"}},"outputs":{"output":{"title":"output","dataType":"anyDataType"}},"dataType":"anyDataType","title":"reroute"},{"id":"11","type":"reroute","position":{"x":523.9549186481242,"y":430.3470431007122},"inputs":{"input":{"title":"input","dataType":"anyDataType"}},"outputs":{"output":{"title":"output","dataType":"anyDataType"}},"dataType":"anyDataType","title":"reroute"},{"id":"12","type":"reroute","position":{"x":738.6865930058369,"y":470.93527168560024},"inputs":{"input":{"title":"input","dataType":"anyDataType"}},"outputs":{"output":{"title":"output","dataType":"anyDataType"}},"dataType":"anyDataType","title":"reroute"},{"id":"13","type":"Function & Variable Creation.function call","position":{"x":951.1776519407233,"y":565.3790620982402},"inputs":{"execOut":{"title":"execOut","dataType":"exec"},"out_0":{"title":"model","dataType":"anyDataType"},"out_1":{"title":"path","dataType":"anyDataType"}},"outputs":{"functionCallExecOut":{"title":"functionCallExecOut","dataType":"exec"}},"nodeRef":"9","title":"predict_on_image"},{"id":"14","type":"comment","comment":"procedure abstract","position":{"x":128.0545540468654,"y":237.54757918954812},"width":1088,"height":270,"zIndex":-1001},{"id":"15","type":"reroute","position":{"x":488.62338828403483,"y":724.8652069323582},"inputs":{"input":{"title":"input","dataType":"keras.model"}},"outputs":{"output":{"title":"output","dataType":"keras.model"}},"dataType":"keras.model","title":"reroute"},{"id":"16","type":"reroute","position":{"x":858.9088709380237,"y":723.9097263229303},"inputs":{"input":{"title":"input","dataType":"keras.model"}},"outputs":{"output":{"title":"output","dataType":"keras.model"}},"dataType":"keras.model","title":"reroute"},{"id":"17","type":"comment","comment":"batch process","position":{"x":129.08730979449,"y":519.5804175640096},"width":990,"height":264,"zIndex":-1001}],"edges":[{"id":"reactflow__edge-1execOut-0execIn","output":"1","input":"0","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-0execOut-6execIn","output":"0","input":"6","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-6execOut-4execIn","output":"6","input":"4","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-6paths-4list","output":"6","input":"4","outputHandle":"paths","inputHandle":"list","dataType":"list","style":{"strokeWidth":2,"stroke":"hsl(300, 100%, 25%)"}},{"id":"reactflow__edge-3execOut-2execIn","output":"3","input":"2","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-3image-2input_image","output":"3","input":"2","outputHandle":"image","inputHandle":"input_image","dataType":"image","style":{"strokeWidth":2,"stroke":"hsl(300, 200%, 25%)"}},{"id":"reactflow__edge-2execOut-5execIn","output":"2","input":"5","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-7out-5input","output":"7","input":"5","outputHandle":"out","inputHandle":"input","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-2predicted-7in_0","output":"2","input":"7","outputHandle":"predicted","inputHandle":"in_0","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-9execOut-3execIn","output":"9","input":"3","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-9out_1-3path","output":"9","input":"3","outputHandle":"out_1","inputHandle":"path","dataType":"string","style":{"strokeWidth":2,"stroke":"hsl(60, 80%, 40%)"}},{"id":"reactflow__edge-9out_0-10input","output":"9","input":"10","outputHandle":"out_0","inputHandle":"input","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-10output-11input","output":"10","input":"11","outputHandle":"output","inputHandle":"input","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-11output-2keras_model","output":"11","input":"2","outputHandle":"output","inputHandle":"keras_model","dataType":"keras.model","style":{"strokeWidth":2,"stroke":"hsl(60, 20%, 80%)"}},{"id":"reactflow__edge-9out_1-8input","output":"9","input":"8","outputHandle":"out_1","inputHandle":"input","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-8output-12input","output":"8","input":"12","outputHandle":"output","inputHandle":"input","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-12output-7in1","output":"12","input":"7","outputHandle":"output","inputHandle":"in1","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-4loopBody-13execOut","output":"4","input":"13","outputHandle":"loopBody","inputHandle":"execOut","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-4element-13out_1","output":"4","input":"13","outputHandle":"element","inputHandle":"out_1","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-0model-15input","output":"0","input":"15","outputHandle":"model","inputHandle":"input","dataType":"keras.model","style":{"strokeWidth":2,"stroke":"hsl(60, 20%, 80%)"}},{"id":"reactflow__edge-15output-16input","output":"15","input":"16","outputHandle":"output","inputHandle":"input","dataType":"keras.model","style":{"strokeWidth":2,"stroke":"hsl(60, 20%, 80%)"}},{"id":"reactflow__edge-16output-13out_0","output":"16","input":"13","outputHandle":"output","inputHandle":"out_0","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}}]}
