# %% [markdown]
# {"nodes":[{"id":"0","type":"Flow Control.sequence","position":{"x":126.5,"y":300.5},"inputs":{"execIn":{"title":"execIn","dataType":"exec"}},"outputs":{"execOut0":{"title":"then 0","dataType":"exec"},"execOut1":{"title":"then 1","dataType":"exec"},"execOut-0":{"title":"then 2","dataType":"exec"}},"title":"sequence"},{"id":"1","type":"Flow Control.main","position":{"x":41,"y":302},"outputs":{"execOut":{"dataType":"exec"}},"title":"main"},{"id":"2","type":"imageio.read_image","position":{"x":371.6579251737664,"y":68.3370032136595},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","value":"channel_0.jpg","dataType":"string"},"mode":{"title":"mode","value":"ImageReadMode.GRAY","dataType":"imageio.ImageReadMode"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"read_image"},{"id":"3","type":"imageio.read_image","position":{"x":373.2005356219263,"y":256.3802954946445},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","value":"channel_1.jpg","dataType":"string"},"mode":{"title":"mode","value":"ImageReadMode.GRAY","dataType":"imageio.ImageReadMode"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"read_image"},{"id":"4","type":"Function & Variable Creation.new function","position":{"x":38.020386014696214,"y":742.368566472095},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"out_0":{"title":"image","dataType":"image"}},"nodeRef":null,"title":"segment_nucleus_rim"},{"id":"5","type":"Function & Variable Creation.function call","position":{"x":645.9250238504313,"y":67.24325589760349},"inputs":{"execOut":{"title":"execOut","dataType":"exec"},"out_0":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"}},"outputs":{"functionCallExecOut":{"title":"functionCallExecOut","dataType":"exec"}},"nodeRef":"4","title":"segment_nucleus_rim"},{"id":"6","type":"Function & Variable Creation.return","position":{"x":1622.5250432656496,"y":749.3470230207231},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"in_0":{"title":"segmented","dataType":"anyDataType"}},"title":"return"},{"id":"7","type":"Function & Variable Creation.new variable","position":{"x":876.3291921093646,"y":67.19160200486064},"inputs":{"execIn":{"dataType":"exec"},"name":{"title":"name","value":"mask","dataType":"anyDataType"},"value":{"title":"value","dataType":"anyDataType"}},"outputs":{"execOut":{"dataType":"exec"}},"title":"new variable"},{"id":"8","type":"Function & Variable Creation.new variable","position":{"x":860.4496516915228,"y":259.31779259358126},"inputs":{"execIn":{"dataType":"exec"},"name":{"title":"name","value":"masked","dataType":"anyDataType"},"value":{"title":"value","dataType":"anyDataType"}},"outputs":{"execOut":{"dataType":"exec"}},"title":"new variable"},{"id":"9","type":"comment","comment":"Create the mask based on the channel 0 image","position":{"x":341.6579251737664,"y":37.19160200486064},"width":760,"height":178,"zIndex":-1001},{"id":"10","type":"Scikiimage.image.mask_image","position":{"x":645.9757575303016,"y":257.04421774381575},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"mask":{"title":"mask","dataType":"numpy.ndarray"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"mask_image"},{"id":"11","type":"Function & Variable Creation.getter","position":{"x":525.4762904927248,"y":404.06872469532436},"outputs":{"getter":{"title":"mask","dataType":"anyDataType"}},"nodeRef":"7"},{"id":"12","type":"Scikiimage.measure.regionprops_table","position":{"x":491.776964831808,"y":498.5286032638867},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"label_image":{"title":"label_image","dataType":"numpy.ndarray"},"intensity_image":{"title":"sampling","value":"None","dataType":"anyDataType"},"properties":{"title":"properties","value":"('label', 'intensity_mean')","dataType":"tuple"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"labels":{"title":"labels","dataType":"numpy.ndarray"},"connectivity":{"title":"connectivity","dataType":"integer"}},"title":"regionprops_table"},{"id":"13","type":"file.save_to_csv","position":{"x":823.3078650024055,"y":497.9247893930295},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","dataType":"string"},"pandas.dataframe":{"title":"pandas dataframe","value":"","dataType":"anyDataType"},"sep":{"title":"sep","value":"\\t","dataType":"string"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"}},"title":"save_to_csv"},{"id":"14","type":"Function & Variable Creation.getter","position":{"x":353.55439737142063,"y":626.0617186846931},"outputs":{"getter":{"title":"masked","dataType":"anyDataType"}},"nodeRef":"8"},{"id":"15","type":"Function & Variable Creation.getter","position":{"x":353.8324302794044,"y":585.8989213412557},"outputs":{"getter":{"title":"mask","dataType":"anyDataType"}},"nodeRef":"7"},{"id":"16","type":"comment","position":{"x":343.2005356219263,"y":226.38029549464449},"width":742,"height":219,"zIndex":-1001},{"id":"17","type":"comment","position":{"x":342.8916945245425,"y":466.7760910380325},"width":725.7220344979639,"height":218.68407899119484,"zIndex":-1001},{"id":"18","type":"Scikiimage.filter.gaussian","position":{"x":257.5725423500212,"y":741.9748149808387},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"sigma":{"title":"sigma","value":1.4,"dataType":"float"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"gaussian"},{"id":"19","type":"Scikiimage.filter.threshold_otsu","position":{"x":508.29110457930483,"y":741.1042644175424},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"nbins":{"title":"nbins","dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"threshold":{"title":"threshold","dataType":"float"}},"title":"threshold_otsu"},{"id":"20","type":"Scikiimage.segmentation.clear_border","position":{"x":1042.1295098858045,"y":756.0686689239114},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"clear_border"},{"id":"21","type":"reroute","position":{"x":356.61259102541266,"y":541.5415801381241},"inputs":{"input":{"title":"input","dataType":"exec"}},"outputs":{"output":{"title":"output","dataType":"exec"}},"dataType":"exec","title":"reroute"},{"id":"22","type":"numpy.binarize_normalized","position":{"x":785.3117431749497,"y":740.6962153051904},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"threshold":{"title":"threshold","dataType":"float"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"binarized":{"dataType":"image"}},"title":"binarize_normalized"},{"id":"23","type":"reroute","position":{"x":503.39100442622043,"y":886.863534460905},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"24","type":"reroute","position":{"x":674.0099853620595,"y":888.5232884162915},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"}],"edges":[{"id":"reactflow__edge-1execOut-0execIn","output":"1","input":"0","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-0execOut0-2execIn","output":"0","input":"2","outputHandle":"execOut0","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-0execOut1-3execIn","output":"0","input":"3","outputHandle":"execOut1","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-2execOut-5execOut","output":"2","input":"5","outputHandle":"execOut","inputHandle":"execOut","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-2image-5out_0","output":"2","input":"5","outputHandle":"image","inputHandle":"out_0","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-5functionCallExecOut-7execIn","output":"5","input":"7","outputHandle":"functionCallExecOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-5in_0-7value","output":"5","input":"7","outputHandle":"in_0","inputHandle":"value","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-3image-10image","output":"3","input":"10","outputHandle":"image","inputHandle":"image","dataType":"image","style":{"strokeWidth":2,"stroke":"hsl(300, 200%, 25%)"}},{"id":"reactflow__edge-3execOut-10execIn","output":"3","input":"10","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-11getter-10mask","output":"11","input":"10","outputHandle":"getter","inputHandle":"mask","dataType":"numpy.ndarray","style":{"strokeWidth":2,"stroke":"hsl(50, 30%, 60%)"}},{"id":"reactflow__edge-10execOut-8execIn","output":"10","input":"8","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-10image-8value","output":"10","input":"8","outputHandle":"image","inputHandle":"value","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-12execOut-13execIn","output":"12","input":"13","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-12labels-13pandas.dataframe","output":"12","input":"13","outputHandle":"labels","inputHandle":"pandas.dataframe","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-14getter-12intensity_image","output":"14","input":"12","outputHandle":"getter","inputHandle":"intensity_image","dataType":"anyDataType","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 50%)"}},{"id":"reactflow__edge-4out_0-18image","output":"4","input":"18","outputHandle":"out_0","inputHandle":"image","dataType":"image","style":{"strokeWidth":2,"stroke":"hsl(300, 200%, 25%)"}},{"id":"reactflow__edge-4execOut-18execIn","output":"4","input":"18","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-18execOut-19execIn","output":"18","input":"19","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-18image-19image","output":"18","input":"19","outputHandle":"image","inputHandle":"image","dataType":"image","style":{"strokeWidth":2,"stroke":"hsl(300, 200%, 25%)"}},{"id":"reactflow__edge-20execOut-6execIn","output":"20","input":"6","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-0execOut-0-21input","output":"0","input":"21","outputHandle":"execOut-0","inputHandle":"input","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-21output-12execIn","output":"21","input":"12","outputHandle":"output","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-15getter-12label_image","output":"15","input":"12","outputHandle":"getter","inputHandle":"label_image","dataType":"numpy.ndarray","style":{"strokeWidth":2,"stroke":"hsl(50, 30%, 60%)"}},{"id":"reactflow__edge-19execOut-22execIn","output":"19","input":"22","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec","style":{"strokeWidth":2,"stroke":"hsl(0, 0%, 0%)"}},{"id":"reactflow__edge-18image-23input","output":"18","input":"23","outputHandle":"image","inputHandle":"input","dataType":"image","style":{"strokeWidth":2,"stroke":"hsl(300, 200%, 25%)"}},{"id":"reactflow__edge-23output-24input","output":"23","input":"24","outputHandle":"output","inputHandle":"input","dataType":"image","style":{"strokeWidth":2,"stroke":"hsl(300, 200%, 25%)"}},{"id":"reactflow__edge-24output-22image","output":"24","input":"22","outputHandle":"output","inputHandle":"image","dataType":"image","style":{"strokeWidth":2,"stroke":"hsl(300, 200%, 25%)"}}]}
